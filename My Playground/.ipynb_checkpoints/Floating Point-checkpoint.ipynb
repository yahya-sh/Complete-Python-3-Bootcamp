# %%
0.1+0.2-0.3
# Out:
# 5.551115123125783e-17

# %%
print(f"{format(0.1, ".20f")} + {format(0.2, ".20f")} - {format(0.3, ".20f")} = {0.1+0.2-0.3}")
print(f"= {format(0.1+0.2-0.3, ".20f")}")
# Out:
# 0.10000000000000000555 + 0.20000000000000001110 - 0.29999999999999998890 = 5.551115123125783e-17
# = 0.00000000000000005551
