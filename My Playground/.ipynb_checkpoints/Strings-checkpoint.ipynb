# %%
text = "Hello"

# %%
text[:-1]
# Out:
# 'Hell'

# %%
text[-1]
# Out:
# 'o'

# %% [markdown]
# # Slicing
# text[start:stop:step]

# %%
text[1:4:2]
# Out:
# 'el'

# %%
text[::2]
# Out:
# 'Hlo'

# %%
len(text)
# Out:
# 5

# %%
text[-5]
# Out:
# 'H'

# %%
text[0:1]
# Out:
# 'H'

# %%
alphabet='abcdefghijklmnopqrqstuvwxyz'

# %%
alphabet[::2]
# Out:
# 'acegikmoqqtvxz'

# %%
alphabet[1::2]
# Out:
# 'bdfhjlnprsuwy'

# %% [markdown]
# # String functions

# %%
placeholder= 'please enter your email here..'

# %%
words = placeholder.split()
for i, word in enumerate(words):
    words[i] = word[0].upper() + word[1:].lower()
placeholder = ' '.join(words)

placeholder
# Out:
# 'Please Enter Your Email Here..'

# %%
message = "Hi   there"

# %%
words = message.split(' ')
words
# Out:
# ['Hi', '', '', 'there']

# %%
list(filter(lambda i: i != '', words))
# Out:
# ['Hi', 'there']
