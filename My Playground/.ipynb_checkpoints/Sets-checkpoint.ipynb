# %%
type({})
# Out:
# dict

# %%
type({1})
# Out:
# set

# %%
type(set())
# Out:
# set

# %%
set('Mississippi')
# Out:
# {'M', 'i', 'p', 's'}

# %%
set("Parallel")
# Out:
# {'P', 'a', 'e', 'l', 'r'}
