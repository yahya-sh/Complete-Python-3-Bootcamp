# %%
"Hello, {}!".format("Yahya")
# Out:
# 'Hello, Yahya!'

# %%
"The {} {} {}".format("quick", "brown", "fox")
# Out:
# 'The quick brown fox'

# %%
"The {2} {1} {0}".format("fox", "brown", "quick")
# Out:
# 'The quick brown fox'

# %%
"The {q} {b} {f}".format(q="quick", b="brown", f="fox")
# Out:
# 'The quick brown fox'

# %%
number = 1234.56789

# %%
f'{number:7.2f}'
# Out:
# '1234.57'

# %%
number = 1234567890.1234

# %%
'{:13.2f}'.format(number)
# Out:
# '1234567890.12'

# %%
number = 1234.1234

# %% [markdown]
# I sat the number of left digits + 1 (for the dot) + right digits to auto fill the white spaces:
#
# 10 + 1 + 2 = 13

# %%
'{:13.2f}'.format(number)
# Out:
# '      1234.12'
